# %%
import tensorflow as tf
import numpy as np
import torch
from torch import nn
from torch.nn import Linear as linear
from torch.nn import ReLU as relu
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
def dataload():
    x=[]
    y=[]
    cars=os.listdir('cars/')
    for i in cars:
        examples=os.listdir('cars/{}/img/'.format(i))
        for j in examples:
            im=np.array(Image.open(r"cars\{}\img\{}".format(i,j)).resize((128, 128)))/255
            if im.shape != (128, 128, 3):
                continue 
            im=(im.reshape((1,128*128*3)).T)
            x.append(im)
            if i=='negative':
                y.append(0)
            else: 
                y.append(1)  
    return x,y

# %%
x,y=dataload()

# %%
x = np.array(x)
y = np.array(y) 
print(x.shape,y.shape)
# Out:
# (1063, 49152, 1) (1063,)

# %%
t=450
plt.imshow(x[t].reshape((128,128,3)))
plt.title(y[t])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.transpose(x,(0,2,1))
x.shape
# Out:
# (1063, 1, 49152)

# %%
model=nn.Sequential(
linear(49152,2024),nn.Dropout(p=0.3),
relu(),
linear(2024,1024),nn.Dropout(p=0.3),
relu(),
linear(1024,512),nn.Dropout(p=0.3),
relu(),
linear(512,256),nn.Dropout(p=0.3),
relu(),
linear(256,128),nn.Dropout(p=0.3),
relu(),
linear(128,1),
nn.Sigmoid())
loss_fn=nn.BCELoss()
optimizer=torch.optim.Adam(model.parameters(),lr=0.001,betas=(0.9, 0.999), weight_decay=1e-5)
if torch.cuda.is_available(): 
 dev = "cuda:0" 
else: 
 dev = "cpu" 
device = torch.device(dev)
model=model.to(device)

# %%
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=49152, out_features=2024, bias=True)
#   (1): Dropout(p=0.3, inplace=False)
#   (2): ReLU()
#   (3): Linear(in_features=2024, out_features=1024, bias=True)
#   (4): Dropout(p=0.3, inplace=False)
#   (5): ReLU()
#   (6): Linear(in_features=1024, out_features=512, bias=True)
#   (7): Dropout(p=0.3, inplace=False)
#   (8): ReLU()
#   (9): Linear(in_features=512, out_features=256, bias=True)
#   (10): Dropout(p=0.3, inplace=False)
#   (11): ReLU()
#   (12): Linear(in_features=256, out_features=128, bias=True)
#   (13): Dropout(p=0.3, inplace=False)
#   (14): ReLU()
#   (15): Linear(in_features=128, out_features=1, bias=True)
#   (16): Sigmoid()
# )

# %%
# dummy_outputs = torch.rand(4)
# dummy_labels = torch.tensor([1., 1., 0., 0.])
# loss = loss_fn(dummy_outputs, dummy_labels)
# print('Total loss for this batch: {}'.format(loss.item()))

# %%
randomize = np.arange(len(x),dtype='int32')
np.random.shuffle(randomize)
x = x[randomize]
y = y[randomize]
print(x.shape)
print(y.shape)
# Out:
# (1063, 1, 49152)
# (1063,)

# %%
x_train=x[0:800]
y_train=y[0:800]
print(x_train.shape,y_train.shape)
# Out:
# (800, 1, 49152) (800,)

# %%
x_test=x[800:]
y_test=y[800:]
print(x_test.shape,y_test.shape)
# Out:
# (263, 1, 49152) (263,)

# %%
def accuracy():
    with torch.no_grad():
        y_pred = model(x_test_t)
    accuracy_test = (y_pred.round() == y_test_t).float().mean()
    with torch.no_grad():
        y_pred = model(x_train_t)
    accuracy_train = (y_pred.round() == y_train_t).float().mean()
    print(f"Accuracy of test set {accuracy_test}\nAccuracy of train set {accuracy_train}")

# %%
def train(n_epochs,x,y,batch_size):
    for epoch in range(n_epochs):
        for i in range(0, len(x), batch_size):
            Xbatch = x[i:i+batch_size]
            # if torch.cuda.is_available(): 
            #     dev = "cuda:0" 
            # else: 
            #     dev = "cpu" 
            # device = torch.device(dev)
            # Xbatch=Xbatch.to(device)
            y_pred = model(Xbatch)
            ybatch = y[i:i+batch_size]
            
            loss = loss_fn(y_pred, ybatch)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        print("#############################################")
        print(f'Finished epoch {epoch}, latest loss {loss}')
        accuracy()

# %%
x_train_t = torch.tensor(x_train, dtype=torch.float32).reshape((x_train.shape[0],49152))
y_train_t = torch.tensor(y_train, dtype=torch.float32).reshape(-1, 1)
x_test_t = torch.tensor(x_test, dtype=torch.float32).reshape((x_test.shape[0],49152))
y_test_t = torch.tensor(y_test, dtype=torch.float32).reshape(-1, 1)
if torch.cuda.is_available(): 
 dev = "cuda:0" 
else: 
 dev = "cpu" 
device = torch.device(dev)
x_train_t= x_train_t.to(device)
y_train_t= y_train_t.to(device)
x_test_t = x_test_t.to(device) 
y_test_t = y_test_t.to(device) 
torch.cuda.is_available()
# Out:
# True

# %%
train(100,x_train_t,y_train_t,32)
# Out:
# #############################################
# Finished epoch 0, latest loss 0.7048519849777222
# Accuracy of test set 0.6121672987937927
# Accuracy of train set 0.6412500143051147
# #############################################
# Finished epoch 1, latest loss 0.6421728134155273
# Accuracy of test set 0.6730037927627563
# Accuracy of train set 0.7174999713897705
# #############################################
# Finished epoch 2, latest loss 0.28614938259124756
# Accuracy of test set 0.806083619594574
# Accuracy of train set 0.8424999713897705
# #############################################
# Finished epoch 3, latest loss 0.35256290435791016
# Accuracy of test set 0.8326995968818665
# Accuracy of train set 0.8549999594688416
# #############################################
# Finished epoch 4, latest loss 0.28632867336273193
# Accuracy of test set 0.8365018963813782
# Accuracy of train set 0.8512499928474426
# #############################################
# Finished epoch 5, latest loss 0.6280511617660522
# Accuracy of test set 0.8593155741691589
# Accuracy of train set 0.8812499642372131
# #############################################
# Finished epoch 6, latest loss 0.28426218032836914
# Accuracy of test set 0.8288973569869995
# Accuracy of train set 0.8824999928474426
# #############################################
# Finished epoch 7, latest loss 0.20178964734077454
# Accuracy of test set 0.8555132746696472
# Accuracy of train set 0.8700000047683716
# #############################################
# Finished epoch 8, latest loss 0.2245407998561859
# Accuracy of test set 0.8593155741691589
# Accuracy of train set 0.887499988079071
# #############################################
# Finished epoch 9, latest loss 0.314378023147583
# Accuracy of test set 0.8555132746696472
# Accuracy of train set 0.89124995470047
# #############################################
# Finished epoch 10, latest loss 0.20302298665046692
# Accuracy of test set 0.8441064357757568
# Accuracy of train set 0.89124995470047
# #############################################
# Finished epoch 11, latest loss 0.19460240006446838
# Accuracy of test set 0.8479087352752686
# Accuracy of train set 0.8824999928474426
# #############################################
# Finished epoch 12, latest loss 0.24313198029994965
# Accuracy of test set 0.8897338509559631
# Accuracy of train set 0.8824999928474426
# #############################################
# Finished epoch 13, latest loss 0.22625970840454102
# Accuracy of test set 0.8783270120620728
# Accuracy of train set 0.90625
# #############################################
# Finished epoch 14, latest loss 0.30092257261276245
# Accuracy of test set 0.8669201731681824
# Accuracy of train set 0.8862499594688416
# #############################################
# Finished epoch 15, latest loss 0.09917689859867096
# Accuracy of test set 0.8707224130630493
# Accuracy of train set 0.9037500023841858
# #############################################
# Finished epoch 16, latest loss 0.22190195322036743
# Accuracy of test set 0.8669201731681824
# Accuracy of train set 0.8999999761581421
# #############################################
# Finished epoch 17, latest loss 0.2849961221218109
# Accuracy of test set 0.8631178736686707
# Accuracy of train set 0.8624999523162842
# #############################################
# Finished epoch 18, latest loss 0.17188876867294312
# Accuracy of test set 0.8707224130630493
# Accuracy of train set 0.8924999833106995
# #############################################
# Finished epoch 19, latest loss 0.28764083981513977
# Accuracy of test set 0.8821292519569397
# Accuracy of train set 0.8987500071525574
# #############################################
# Finished epoch 20, latest loss 0.14758628606796265
# Accuracy of test set 0.8783270120620728
# Accuracy of train set 0.8799999952316284
# #############################################
# Finished epoch 21, latest loss 0.30784934759140015
# Accuracy of test set 0.8783270120620728
# Accuracy of train set 0.8899999856948853
# #############################################
# Finished epoch 22, latest loss 0.22582989931106567
# Accuracy of test set 0.8631178736686707
# Accuracy of train set 0.90625
# #############################################
# Finished epoch 23, latest loss 0.29436346888542175
# Accuracy of test set 0.802281379699707
# Accuracy of train set 0.8187499642372131
# #############################################
# Finished epoch 24, latest loss 0.41121459007263184
# Accuracy of test set 0.8631178736686707
# Accuracy of train set 0.8524999618530273
# #############################################
# Finished epoch 25, latest loss 0.19597294926643372
# Accuracy of test set 0.8593155741691589
# Accuracy of train set 0.8937499523162842
# #############################################
# Finished epoch 26, latest loss 0.25738444924354553
# Accuracy of test set 0.8783270120620728
# Accuracy of train set 0.89124995470047
# #############################################
# Finished epoch 27, latest loss 0.14887915551662445
# Accuracy of test set 0.8517110347747803
# Accuracy of train set 0.9087499976158142
# #############################################
# Finished epoch 28, latest loss 0.1819722205400467
# Accuracy of test set 0.8555132746696472
# Accuracy of train set 0.9199999570846558
# #############################################
# Finished epoch 29, latest loss 0.13954061269760132
# Accuracy of test set 0.874524712562561
# Accuracy of train set 0.9012500047683716
# #############################################
# Finished epoch 30, latest loss 0.17947576940059662
# Accuracy of test set 0.8479087352752686
# Accuracy of train set 0.8924999833106995
# #############################################
# Finished epoch 31, latest loss 0.1676613986492157
# Accuracy of test set 0.8441064357757568
# Accuracy of train set 0.9012500047683716
# #############################################
# Finished epoch 32, latest loss 0.23453621566295624
# Accuracy of test set 0.8517110347747803
# Accuracy of train set 0.8612499833106995
# #############################################
# Finished epoch 33, latest loss 0.15944819152355194
# Accuracy of test set 0.8821292519569397
# Accuracy of train set 0.8899999856948853
# #############################################
# Finished epoch 34, latest loss 0.22584941983222961
# Accuracy of test set 0.8593155741691589
# Accuracy of train set 0.89124995470047
# #############################################
# Finished epoch 35, latest loss 0.20022368431091309
# Accuracy of test set 0.8821292519569397
# Accuracy of train set 0.9087499976158142
# #############################################
# Finished epoch 36, latest loss 0.31017059087753296
# Accuracy of test set 0.8631178736686707
# Accuracy of train set 0.9137499928474426
# #############################################
# Finished epoch 37, latest loss 0.21434077620506287
# Accuracy of test set 0.874524712562561
# Accuracy of train set 0.9024999737739563
# #############################################
# Finished epoch 38, latest loss 0.28595471382141113
# Accuracy of test set 0.8897338509559631
# Accuracy of train set 0.9174999594688416
# #############################################
# Finished epoch 39, latest loss 0.24548354744911194
# Accuracy of test set 0.874524712562561
# Accuracy of train set 0.8974999785423279
# #############################################
# Finished epoch 40, latest loss 0.17573682963848114
# Accuracy of test set 0.8783270120620728
# Accuracy of train set 0.8999999761581421
# #############################################
# Finished epoch 41, latest loss 0.3067905306816101
# Accuracy of test set 0.8441064357757568
# Accuracy of train set 0.8924999833106995
# #############################################
# Finished epoch 42, latest loss 0.39342010021209717
# Accuracy of test set 0.9011406898498535
# Accuracy of train set 0.8837499618530273
# #############################################
# Finished epoch 43, latest loss 0.14908717572689056
# Accuracy of test set 0.8555132746696472
# Accuracy of train set 0.9087499976158142
# #############################################
# Finished epoch 44, latest loss 0.16835932433605194
# Accuracy of test set 0.8517110347747803
# Accuracy of train set 0.887499988079071
# #############################################
# Finished epoch 45, latest loss 0.2077813744544983
# Accuracy of test set 0.8821292519569397
# Accuracy of train set 0.9137499928474426
# #############################################
# Finished epoch 46, latest loss 0.2547121047973633
# Accuracy of test set 0.8897338509559631
# Accuracy of train set 0.9162499904632568
# #############################################
# Finished epoch 47, latest loss 0.14501358568668365
# Accuracy of test set 0.8707224130630493
# Accuracy of train set 0.8924999833106995
# #############################################
# Finished epoch 48, latest loss 0.21143051981925964
# Accuracy of test set 0.8441064357757568
# Accuracy of train set 0.8537499904632568
# #############################################
# Finished epoch 49, latest loss 0.2157217413187027
# Accuracy of test set 0.8897338509559631
# Accuracy of train set 0.9099999666213989
# #############################################
# Finished epoch 50, latest loss 0.1275598704814911
# Accuracy of test set 0.8479087352752686
# Accuracy of train set 0.9049999713897705
# #############################################
# Finished epoch 51, latest loss 0.20186704397201538
# Accuracy of test set 0.8821292519569397
# Accuracy of train set 0.9087499976158142
# #############################################
# Finished epoch 52, latest loss 0.38752511143684387
# Accuracy of test set 0.7566539645195007
# Accuracy of train set 0.8174999952316284
# #############################################
# Finished epoch 53, latest loss 0.22771427035331726
# Accuracy of test set 0.8669201731681824
# Accuracy of train set 0.9037500023841858
# #############################################
# Finished epoch 54, latest loss 0.5145737528800964
# Accuracy of test set 0.8403041958808899
# Accuracy of train set 0.9149999618530273
# #############################################
# Finished epoch 55, latest loss 0.2836860716342926
# Accuracy of test set 0.8707224130630493
# Accuracy of train set 0.8949999809265137
# #############################################
# Finished epoch 56, latest loss 0.19596895575523376
# Accuracy of test set 0.8365018963813782
# Accuracy of train set 0.8987500071525574
# #############################################
# Finished epoch 57, latest loss 0.17909325659275055
# Accuracy of test set 0.8631178736686707
# Accuracy of train set 0.8787499666213989
# #############################################
# Finished epoch 58, latest loss 0.2023683786392212
# Accuracy of test set 0.8212927579879761
# Accuracy of train set 0.8025000095367432
# #############################################
# Finished epoch 59, latest loss 0.13180750608444214
# Accuracy of test set 0.8631178736686707
# Accuracy of train set 0.9112499952316284
# #############################################
# Finished epoch 60, latest loss 0.22256852686405182
# Accuracy of test set 0.8288973569869995
# Accuracy of train set 0.8662499785423279
# #############################################
# Finished epoch 61, latest loss 0.38294661045074463
# Accuracy of test set 0.8365018963813782
# Accuracy of train set 0.9037500023841858
# #############################################
# Finished epoch 62, latest loss 0.1292901635169983
# Accuracy of test set 0.8403041958808899
# Accuracy of train set 0.9149999618530273
# #############################################
# Finished epoch 63, latest loss 0.23192137479782104
# Accuracy of test set 0.7908745408058167
# Accuracy of train set 0.8137499690055847
# #############################################
# Finished epoch 64, latest loss 0.27656859159469604
# Accuracy of test set 0.8136882185935974
# Accuracy of train set 0.8299999833106995
# #############################################
# Finished epoch 65, latest loss 0.8070003986358643
# Accuracy of test set 0.8136882185935974
# Accuracy of train set 0.8799999952316284
# #############################################
# Finished epoch 66, latest loss 0.4589102268218994
# Accuracy of test set 0.8517110347747803
# Accuracy of train set 0.8887499570846558
# #############################################
# Finished epoch 67, latest loss 0.28000426292419434
# Accuracy of test set 0.8517110347747803
# Accuracy of train set 0.90625
# #############################################
# Finished epoch 68, latest loss 0.11586345732212067
# Accuracy of test set 0.8479087352752686
# Accuracy of train set 0.90625
# #############################################
# Finished epoch 69, latest loss 0.15970264375209808
# Accuracy of test set 0.802281379699707
# Accuracy of train set 0.8762499690055847
# #############################################
# Finished epoch 70, latest loss 0.22547900676727295
# Accuracy of test set 0.8631178736686707
# Accuracy of train set 0.89124995470047
# #############################################
# Finished epoch 71, latest loss 0.3235984444618225
# Accuracy of test set 0.8517110347747803
# Accuracy of train set 0.8799999952316284
# #############################################
# Finished epoch 72, latest loss 0.13793765008449554
# Accuracy of test set 0.8593155741691589
# Accuracy of train set 0.918749988079071
# #############################################
# Finished epoch 73, latest loss 0.266248881816864
# Accuracy of test set 0.8783270120620728
# Accuracy of train set 0.8962500095367432
# #############################################
# Finished epoch 74, latest loss 0.2683372497558594
# Accuracy of test set 0.8479087352752686
# Accuracy of train set 0.8799999952316284
# #############################################
# Finished epoch 75, latest loss 0.2624477744102478
# Accuracy of test set 0.8821292519569397
# Accuracy of train set 0.9437499642372131
# #############################################
# Finished epoch 76, latest loss 0.3420482873916626
# Accuracy of test set 0.8250950574874878
# Accuracy of train set 0.8949999809265137
# #############################################
# Finished epoch 77, latest loss 0.2550317943096161
# Accuracy of test set 0.8631178736686707
# Accuracy of train set 0.8962500095367432
# #############################################
# Finished epoch 78, latest loss 0.11878765374422073
# Accuracy of test set 0.874524712562561
# Accuracy of train set 0.9399999976158142
# #############################################
# Finished epoch 79, latest loss 0.5042362809181213
# Accuracy of test set 0.7680608034133911
# Accuracy of train set 0.8075000047683716
# #############################################
# Finished epoch 80, latest loss 0.13747595250606537
# Accuracy of test set 0.8136882185935974
# Accuracy of train set 0.8887499570846558
# #############################################
# Finished epoch 81, latest loss 0.11913572251796722
# Accuracy of test set 0.8783270120620728
# Accuracy of train set 0.9350000023841858
# #############################################
# Finished epoch 82, latest loss 0.14831985533237457
# Accuracy of test set 0.8935360908508301
# Accuracy of train set 0.8862499594688416
# #############################################
# Finished epoch 83, latest loss 0.17364922165870667
# Accuracy of test set 0.8707224130630493
# Accuracy of train set 0.9037500023841858
# #############################################
# Finished epoch 84, latest loss 0.2723960876464844
# Accuracy of test set 0.7832699418067932
# Accuracy of train set 0.8499999642372131
# #############################################
# Finished epoch 85, latest loss 0.1691584587097168
# Accuracy of test set 0.8403041958808899
# Accuracy of train set 0.9162499904632568
# #############################################
# Finished epoch 86, latest loss 0.18877039849758148
# Accuracy of test set 0.8707224130630493
# Accuracy of train set 0.9162499904632568
# #############################################
# Finished epoch 87, latest loss 0.17219647765159607
# Accuracy of test set 0.8935360908508301
# Accuracy of train set 0.9124999642372131
# #############################################
# Finished epoch 88, latest loss 0.1281905472278595
# Accuracy of test set 0.8859315514564514
# Accuracy of train set 0.9012500047683716
# #############################################
# Finished epoch 89, latest loss 0.19613052904605865
# Accuracy of test set 0.8288973569869995
# Accuracy of train set 0.9012500047683716
# #############################################
# Finished epoch 90, latest loss 0.12362751364707947
# Accuracy of test set 0.8441064357757568
# Accuracy of train set 0.8824999928474426
# #############################################
# Finished epoch 91, latest loss 0.19095569849014282
# Accuracy of test set 0.8707224130630493
# Accuracy of train set 0.8949999809265137
# #############################################
# Finished epoch 92, latest loss 0.14456379413604736
# Accuracy of test set 0.8897338509559631
# Accuracy of train set 0.9012500047683716
# #############################################
# Finished epoch 93, latest loss 0.2931984066963196
# Accuracy of test set 0.8821292519569397
# Accuracy of train set 0.8812499642372131
# #############################################
# Finished epoch 94, latest loss 0.11514587700366974
# Accuracy of test set 0.8631178736686707
# Accuracy of train set 0.9399999976158142
# #############################################
# Finished epoch 95, latest loss 0.09110822528600693
# Accuracy of test set 0.8859315514564514
# Accuracy of train set 0.9099999666213989
# #############################################
# Finished epoch 96, latest loss 0.143868088722229
# Accuracy of test set 0.8821292519569397
# Accuracy of train set 0.9149999618530273
# #############################################
# Finished epoch 97, latest loss 0.10080459713935852
# Accuracy of test set 0.8935360908508301
# Accuracy of train set 0.9412499666213989
# #############################################
# Finished epoch 98, latest loss 0.08755344152450562
# Accuracy of test set 0.8973383903503418
# Accuracy of train set 0.9387499690055847
# #############################################
# Finished epoch 99, latest loss 0.10804444551467896
# Accuracy of test set 0.8935360908508301
# Accuracy of train set 0.918749988079071

# %%
accuracy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 accuracy()
#
# Cell In[2], line 2, in accuracy()
#       1 def accuracy():
# ----> 2     with torch.no_grad():
#       3         y_pred = model(x_test_t)
#       4     accuracy_test = (y_pred.round() == y_test_t).float().mean()
#
# NameError: name 'torch' is not defined

# %%
with torch.no_grad():
    y_pred=model(x_test_t)
# for i in range (len(x_test)):
#     if y_pred[i].round()!=y_test_t[i]:
        # print(i)
        # plt.imshow(x_test[i].reshape((128,128,3)))
        # plt.figure()
        # plt.title(y_pred[i].round())
        # plt.show

# %%
def test_pic():
    im=np.array(Image.open(r"Test_pictures\t.jpg").resize((128, 128)))/255
    x=np.array(im)
    x=x.reshape(-1,1).T
    x_t=torch.tensor(x,dtype=torch.float32).to(device)
    with torch.no_grad():
        y_pred=model(x_t)
    if y_pred>0.2:
        print("It is a car",y_pred)
    else:
        print("Not a car",y_pred)
    plt.imshow(im.reshape((128,128,3)))
    plt.title(y_pred>0.5)
    plt.show

# %%
test_pic()
np.arra
# Out:
# It is a car tensor([[0.9469]], device='cuda:0')

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# x_train_t.is_cuda
torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# device(type='cuda', index=0)

# %%
np.
